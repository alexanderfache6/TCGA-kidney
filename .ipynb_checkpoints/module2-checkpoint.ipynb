# %% [markdown]
# # Module 2

# %% [markdown]
# ---
#
# ## Imports

# %%
import copy
import cv2
import glob
import imageio
import IPython.display as display
import matplotlib.pyplot as plt
import numpy as np
import os
import pathlib
import pandas as pd
from PIL import Image
from scipy import ndimage, stats
import seaborn as sb
from skimage import color, feature, filters, measure
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, normalize
from sklearn.utils import shuffle
import random
from tqdm import tqdm

# %% [markdown]
# ---
#
# ## Helpers

# %%
def determine_class(file_dir, classes):
    path = np.char.split(file_dir, sep ='\\')
    file_name = path.item(0)[-1]
    for i in range(0, len(classes)):
        if classes[i] in file_name:
            return i
    return -1

# %% [markdown]
# ---
#
# ## Load Images

# %%
current_dir = os.getcwd()
data_dir = current_dir + '\\data_augmented'
image_files = np.array(glob.glob(data_dir + '/*.png'))

classes = np.array(['Necrosis', 'Stroma', 'Tumor'])

augmented_images_size = (224, 224, 3)
augmented_images = np.empty((0, augmented_images_size[0], augmented_images_size[1], augmented_images_size[2]), dtype=np.uint8)
augmented_labels = np.empty((0,), dtype=np.uint8)
augmented_images_files = np.empty((0, 1))

# indices = np.array(np.random.randint(0, len(image_files), 1000))
FIRST_i = 26000
LAST_i  = len(image_files)

for current_image_file in tqdm(image_files[FIRST_i:LAST_i]):
    current_image = np.expand_dims(np.array(Image.open(current_image_file)).astype(np.uint8), axis=0)    
    current_image_label = determine_class(current_image_file, classes)

    augmented_images = np.append(augmented_images, current_image, axis=0)
    augmented_labels = np.append(augmented_labels, np.expand_dims(current_image_label, axis=0), axis=0)

    current_image_file = np.expand_dims(current_image_file, axis=0)
    augmented_images_files = np.append(augmented_images_files, np.expand_dims(current_image_file, axis=0), axis=0)

print()
print('Images:', augmented_images.shape)
print('Labels:', augmented_labels.shape)
print('Files:', augmented_images_files.shape)
# print(augmented_images_files[0:np.min([augmented_images_files.shape[0], 10])])
# Out:
# Images: (730, 224, 224, 3)
# Labels: (730,)
# Files: (730, 1)

# %%
# i = 1
# print('Labels:', augmented_labels[i])
# print('Files:', augmented_images_files[i])

# fig = plt.figure()
# plt.xticks([])
# plt.yticks([])
# plt.grid(False)
# plt.title('augmented_images['+str(i)+']')
# plt.imshow(cv2.cvtColor(augmented_images[i], cv2.COLOR_BGR2RGB))

print(classes)
print(np.unique(augmented_labels, return_counts=True))
# Out:
# ['Necrosis' 'Stroma' 'Tumor']
# (array([2]), array([730], dtype=int64))

# %% [markdown]
# ---
#
# ## Feature Extractors

# %% [markdown]
# ### Color

# %%
def extract_rgb(image):
    r, g, b = cv2.split(image)

    if view_plots:
        fig = plt.figure()
        plt.subplot(1, 3, 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(r, cv2.COLOR_BGR2RGB))
        plt.xlabel('R')
        plt.subplot(1, 3, 2)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(g, cv2.COLOR_BGR2RGB))
        plt.xlabel('G')
        plt.subplot(1, 3, 3)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(b, cv2.COLOR_BGR2RGB))
        plt.xlabel('B')    
    
    rr = stats.describe(r.flatten())
    gg = stats.describe(g.flatten())
    bb = stats.describe(b.flatten())
    
    return np.array([rr.minmax[0], rr.minmax[1], rr.mean, rr.variance, rr.skewness, rr.kurtosis, gg.minmax[0], gg.minmax[1], gg.mean, gg.variance, gg.skewness, gg.kurtosis, bb.minmax[0], bb.minmax[1], bb.mean, bb.variance, bb.skewness, bb.kurtosis], dtype=np.float32), r, g, b

# %%
def extract_hsv(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(image)

    if view_plots:
        fig = plt.figure()
        plt.subplot(1, 3, 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(h, cv2.COLOR_BGR2RGB))
        plt.xlabel('H')
        plt.subplot(1, 3, 2)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(s, cv2.COLOR_BGR2RGB))
        plt.xlabel('S')
        plt.subplot(1, 3, 3)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(v, cv2.COLOR_BGR2RGB))
        plt.xlabel('V')
    
    hh = stats.describe(h.flatten())
    ss = stats.describe(s.flatten())
    vv = stats.describe(v.flatten())
    
    return np.array([hh.minmax[0], hh.minmax[1], hh.mean, hh.variance, hh.skewness, hh.kurtosis, ss.minmax[0], ss.minmax[1], ss.mean, ss.variance, ss.skewness, ss.kurtosis, vv.minmax[0], vv.minmax[1], vv.mean, vv.variance, vv.skewness, vv.kurtosis], dtype=np.float32), h, s, v

# %%
def extract_lab(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(image)

    if view_plots:
        fig = plt.figure()
        plt.subplot(1, 3, 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(l, cv2.COLOR_BGR2RGB))
        plt.xlabel('L')
        plt.subplot(1, 3, 2)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(a, cv2.COLOR_BGR2RGB))
        plt.xlabel('A')
        plt.subplot(1, 3, 3)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(b, cv2.COLOR_BGR2RGB))
        plt.xlabel('B')
    
    ll = stats.describe(l.flatten())
    aa = stats.describe(a.flatten())
    bb = stats.describe(b.flatten())
    
    return np.array([ll.minmax[0], ll.minmax[1], ll.mean, ll.variance, ll.skewness, ll.kurtosis, aa.minmax[0], aa.minmax[1], aa.mean, aa.variance, aa.skewness, aa.kurtosis, bb.minmax[0], bb.minmax[1], bb.mean, bb.variance, bb.skewness, bb.kurtosis], dtype=np.float32), l, a, b

# %% [markdown]
# ### Texture

# %%
#for extract_glcm()

inertia_temp = np.zeros((256, 256))
for i in range(0, inertia_temp.shape[0]):
    for j in range(0, inertia_temp.shape[1]):
        inertia_temp[i, j] = (i-j)^2

# %%
def extract_glcm(image):
    offset = [1] #pixel
    directions = np.asarray([np.pi*i/4 for i in range(0, 8)]) #radian angles

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    glcm = feature.greycomatrix(image, distances=offset, angles=directions).astype(np.uint8)
    
    contrast = feature.greycoprops(glcm, prop='contrast')
    dissimilarity = feature.greycoprops(glcm, prop='dissimilarity')
    homogeneity = feature.greycoprops(glcm, prop='homogeneity')
    ASM = feature.greycoprops(glcm, prop='ASM')
    energy = feature.greycoprops(glcm, prop='energy')
    correlation = feature.greycoprops(glcm, prop='correlation')
        
    #inertia
    #maxprop
    inertia = []
    maxprop = []
    for n in range(0, glcm.shape[3]):
        inertia.append(np.sum(np.multiply(inertia_temp, glcm[:, :, 0, n])))
        maxprop.append(np.max(glcm[:, :, 0, n]))
    
    #TODO
    #cluster shade, cluster prominance

    return np.array([np.mean(contrast), np.std(contrast), np.min(contrast), np.max(contrast), np.mean(dissimilarity), np.std(dissimilarity), np.min(dissimilarity), np.max(dissimilarity), np.mean(homogeneity), np.std(homogeneity), np.min(homogeneity), np.max(homogeneity), np.mean(ASM), np.std(ASM), np.min(ASM), np.max(ASM), np.mean(energy), np.std(energy), np.min(energy), np.max(energy), np.mean(correlation), np.std(correlation), np.min(correlation), np.max(correlation), np.mean(inertia), np.std(inertia), np.min(inertia), np.max(inertia), np.mean(maxprop), np.std(maxprop), np.min(maxprop), np.max(maxprop)], dtype=np.float32)

# %%
def extract_shannon_entropy(image):
    return np.array([measure.shannon_entropy(image)])

# %%
def extract_signaltonoiseratio(image, axis=None, ddof=0):
    a = np.asanyarray(image)
    m = a.mean(axis)
    sd = a.std(axis=axis, ddof=ddof)
    return np.array([np.where(sd == 0, 0, m/sd)])

# %%
from scipy.ndimage import gaussian_laplace as log

def extract_laplacianofgaussian(image):
    # Convolute a gaussian kernel and a laplace kernel
    result = log(image, sigma=1)
    channel1, channel2, channel3 = cv2.split(result)
    
    if view_plots:
        fig = plt.figure()
        plt.subplot(1, 3, 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(channel1, cv2.COLOR_BGR2RGB))
        plt.xlabel('1')
        plt.subplot(1, 3, 2)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(channel2, cv2.COLOR_BGR2RGB))
        plt.xlabel('2')
        plt.subplot(1, 3, 3)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(channel3, cv2.COLOR_BGR2RGB))
        plt.xlabel('3')
    
#     return log(image, sigma=1)

# %%
def extract_histogram(image):
    hist = cv2.calcHist([image], [0], None, [256], [0, 256])
    hh = stats.describe(hist)
    
    return np.array([hh.minmax[0], hh.minmax[1], hh.mean, hh.variance, hh.skewness, hh.kurtosis], dtype=np.float32)

# %% [markdown]
# ### Morphological

# %%
#return mse of vertical and horizontal symmetry

def extract_symmetry(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image_flip_vertical = image[::-1, :]
    image_flip_horizontal = image[:, ::-1]
    
    mse_vertical = np.sum(np.power(image - image_flip_vertical, 2)) / (image.shape[0] * image.shape[1])
    mse_horizontal = np.sum(np.power(image - image_flip_horizontal, 2)) / (image.shape[0] * image.shape[1])
    
    if view_plots:
        fig = plt.figure()
        plt.subplot(1, 2, 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(image_flip_vertical, cv2.COLOR_BGR2RGB))
        plt.xlabel('Flip Vertical')
        plt.subplot(1, 2, 2)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(image_flip_horizontal, cv2.COLOR_BGR2RGB))
        plt.xlabel('Flip Horizontal')
    
    return mse_vertical, mse_horizontal

# %%
def extract_centerofmass(image):
    return ndimage.measurements.center_of_mass(image) #(row, column, depth)

# %%
def extract_percentwhitedarkpixels(image):
    num_pixels = np.prod(image.shape)
    
    mask = image > 220 #{0, 1} get all high value pixels in RGB channels
    white_mask = np.logical_and(np.logical_and(mask[:, :, 0], mask[:, :, 1]), mask[:, :, 2])

    num_white_pixels = np.sum(white_mask)
    
    mask = image < 100 #{0, 1} get all low value pixels in RGB channels
    black_mask = np.logical_and(np.logical_and(mask[:, :, 0], mask[:, :, 1]), mask[:, :, 2])

    num_black_pixels = np.sum(black_mask)
    
    if view_plots:
        fig = plt.figure()
        plt.subplot(1, 3, 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(mask.astype(np.uint8)*255, cv2.COLOR_BGR2RGB))
        plt.xlabel('mask')
        plt.subplot(1, 3, 2)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(white_mask.astype(np.uint8)*255, cv2.COLOR_BGR2RGB))
        plt.xlabel('white mask')
        plt.subplot(1, 3, 3)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(black_mask.astype(np.uint8)*255, cv2.COLOR_BGR2RGB))
        plt.xlabel('black mask')
    
    return np.array([(100*num_white_pixels) / num_pixels, (100*num_black_pixels) / num_pixels], dtype=np.float32)

# %%
def extract_centroids(image):
    # Find the centroid of the 224x224x3 normalized image
    # Return a tuple of 2 values, in the form of(x-centroid, y-centroid) 
    grayimg = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(grayimg, 127, 255, 0)
    M = cv2.moments(thresh)
    if M['m00'] != 0:
        cX = int(M['m10'] / M['m00']) 
        cY = int(M['m01'] / M['m00'])
        return np.array((cX, cY), dtype=np.float32)
    else:
        return np.array((0, 0), dtype=np.float32)

# %%
# https://stackoverflow.com/questions/41175803/counting-number-of-cells-and-nucleus-using-watershed-skikit-image

from skimage.morphology import watershed
from skimage.feature import peak_local_max
from skimage.measure import regionprops

def extract_numcells(image):
    image = color.rgb2gray(image)
    image = image < filters.threshold_otsu(image)
    distance = ndimage.distance_transform_edt(image)
    local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)), labels=image)

    markers, num_features = ndimage.label(local_maxi)
    labels = watershed(-distance, markers, mask=image)
    regions = regionprops(labels)
    regions = [r for r in regions if r.area > 60]

#     print('Number of cells:', len(regions) - 1)
    
    return np.array([len(regions) - 1])

# %%
def extract_numcorners(image):
    # Harris Corner detect with OpenCV
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = np.float32(gray)
    dst = cv2.cornerHarris(gray, 2, 3, 0.04)
    dst = cv2.dilate(dst, None)
    # Apply thresholding
    imgcpy = copy.deepcopy(image)
    imgcpy[dst>0.015*dst.max()]=[0,255,0]

    return np.array([np.sum(dst>0.015*dst.max())])

# %%
def extract_proportionedgepixel(image):
    edges_image = cv2.Canny(image, 100, 200) #{0, 255}

    if view_plots:
        fig = plt.figure(figsize=(2, 2))
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(edges_image, cv2.COLOR_BGR2RGB))
        plt.xlabel('Canny')
        
    return np.array([np.sum(edges_image == 255) / np.prod(edges_image.shape)], dtype=np.float32)

# %% [markdown]
# ---
#
# ## Extract Features

# %%
view_plots = False

# %%
num_features = 18 + 18 + 18 + 32 + 1 + 6 + 2 + 1 + 3 + 2 + 2 + 1 + 1 + 1 #D

data_features = np.empty((0, num_features), dtype=np.float32) #NxD
data_labels = np.empty((0,), dtype=np.int8) #1xD

for i in tqdm(range(0, augmented_images.shape[0])):
    if view_plots:
        fig = plt.figure(figsize=(2, 2))
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(cv2.cvtColor(augmented_images[i], cv2.COLOR_BGR2RGB))
        plt.xlabel('[' + str(i) + ']')

    current_data_features = np.array([], dtype=np.float32)

    #---------- Color ----------
    
    out = extract_rgb(augmented_images[i])
    current_data_features = np.append(current_data_features, out[0], axis=0) #18
    # r = out[1]
    # g = out[2]
    # b = out[3]

    out = extract_hsv(augmented_images[i])
    current_data_features = np.append(current_data_features, out[0], axis=0) #18
    # h = out[1]
    # s = out[2]
    # v = out[3]

    out = extract_lab(augmented_images[i])
    current_data_features = np.append(current_data_features, out[0], axis=0) #18
    # l = out[1]
    # a = out[2]
    # bb = out[3]
    
    #---------- Texture ----------

    out = extract_glcm(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #32
    
    out = extract_shannon_entropy(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #1
        
    
    out = extract_histogram(augmented_images[i])
    current_data_features = np.append(current_data_features, out[:, 0], axis=0) #6
    
    #---------- Morphological ----------
    
    out = extract_symmetry(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #2

    out = extract_signaltonoiseratio(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #1

    out = extract_centerofmass(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #3
    
    out = extract_percentwhitedarkpixels(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #2

    out = extract_centroids(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #2
    
    out = extract_numcells(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #1
    
    out = extract_numcorners(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #1
    
    out = extract_proportionedgepixel(augmented_images[i])
    current_data_features = np.append(current_data_features, out, axis=0) #1
    
    data_features = np.append(data_features, np.expand_dims(current_data_features, axis=0), axis=0)
    data_labels = np.append(data_labels, np.expand_dims(augmented_labels[i], axis=0), axis=0)

print('Data Features:', data_features.shape)
print('Data Labels:', data_labels.shape)
# Out:
# Data Features: (730, 106)
# Data Labels: (730,)

# %%
print('FIRST_i:', FIRST_i)
print('LAST_i:', LAST_i)
# Out:
# FIRST_i: 26000
# LAST_i: 26730

# %%
if FIRST_i == 0:
    # RUN FOR FIRST INSTANCE
    np.savetxt('PYTHON_FEATURES.csv', data_features, delimiter=',')
    np.savetxt('PYTHON_LABELS.csv', data_labels, delimiter=',')
else:
    data_features_prev = np.loadtxt('Module3/PYTHON_FEATURES.csv', delimiter=',')
    data_labels_prev = np.loadtxt('Module3/PYTHON_LABELS.csv', delimiter=',')

    print(data_features_prev.shape)
    print(data_labels_prev.shape)
    print('----')

    data_features_combined = np.append(data_features_prev, data_features, axis=0)
    data_labels_combined = np.append(data_labels_prev, data_labels, axis=0)

    print(data_features_combined.shape)
    print(data_labels_combined.shape)

    np.savetxt('Module3/PYTHON_FEATURES.csv', data_features_combined, delimiter=',')
    np.savetxt('Module3/PYTHON_LABELS.csv', data_labels_combined, delimiter=',')
# Out:
# (26000, 106)
# (26000,)
# ----
# (26730, 106)
# (26730,)

# %%
# i = 0
# data = data_features[i]
# print(data)
# current_image = np.expand_dims(np.array(Image.open(augmented_images_files[i][0])).astype(np.uint8), axis=0)[0]

# b = cv2.calcHist([current_image[:, :, 0]], [0], None, [256], [0, 256])
# g = cv2.calcHist([current_image[:, :, 1]], [0], None, [256], [0, 256])
# r = cv2.calcHist([current_image[:, :, 2]], [0], None, [256], [0, 256])

# # show the plotting graph of an image
# plt.plot(b, 'b')
# plt.plot(g, 'g')
# plt.plot(r, 'r')
# plt.show()

# %% [markdown]
# ### Plot Features

# %%
# grid = (5, 5)

# ax = plt.figure(figsize=(20, 10))

# for i in tqdm(range(0, np.min([data_features.shape[0], grid[0]*grid[1]]))):
#     plt.subplot(grid[0], grid[1], i+1)
#     plt.xticks([])
#     plt.grid(False)
#     plt.scatter(range(0, num_features), data_features[i, :], s=5)
#     plt.xlabel(classes[data_labels[i]])

# %%
scaler = MinMaxScaler(feature_range=[0, 1]) #scale data to [0, 1] range
X_scaled = scaler.fit_transform(data_features)
print(X_scaled.shape)
# Out:
# (1000, 106)

# %%
grid = (5, 5)

ax = plt.figure(figsize=(20, 10))

for i in tqdm(range(0, np.min([X_scaled.shape[0], grid[0]*grid[1]]))):
    plt.subplot(grid[0], grid[1], i+1)
    plt.xticks([])
    plt.grid(False)
    plt.scatter(range(0, num_features), X_scaled[i, :], s=5)
    plt.xlabel(classes[data_labels[i]])

# %% [markdown]
# ---
#
# ## Principal Component Analysis (PCA)

# %%
current_dir = os.getcwd()
save_dir = current_dir + '\\Module2'
print(save_dir)
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
# Out:
# C:\Users\alexa\Documents\GitHub\TCGA-kidney\Module2

# %%
num_features = X_scaled.shape[1] #N > D
desired_explained_variance = [0.80, 0.85, .90, .95, .98, .99, .999]
filename = save_dir + '\\pca_'+'f{:03d}'.format(num_features)

#----

pca = PCA()
pca.fit(X_scaled)

explained_variance = pca.explained_variance_ratio_
components = pca.components_

fig, ((ax1), (ax2)) = plt.subplots(nrows=2, ncols=1, figsize=(20, 10))

ax1 = plt.subplot(2, 1, 1)
plt.xticks(np.arange(0, num_features, (1 if num_features < 10 else 5)))
plt.ylim(0, 1)
plt.xlabel('Component #')
plt.ylabel('Individual Recovered Variance')
plt.title('Scree Plot')
plt.scatter(np.arange(0, num_features), explained_variance)

ax2 = plt.subplot(2, 1, 2)
plt.xticks(np.arange(0, num_features, (1 if num_features < 10 else 5)))
plt.ylim(0, 1.05)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Recovered Variance')
plt.title('Cumulative Recovered Variance')
plt.plot(np.cumsum(explained_variance))

plt.tight_layout()

file = open(filename + '.txt', 'w')
for desired in desired_explained_variance:
    num_features_needed = np.where((np.cumsum(explained_variance) > desired) == 1)[0][0]
    line = '%d components needed to explain %.2f%% of variance' % (num_features_needed, desired*100)
    print(line)
    file.write(line + '\n')
file.close()

fig.savefig(filename + '.png')
# Out:
# 6 components needed to explain 80.00% of variance
# 8 components needed to explain 85.00% of variance
# 12 components needed to explain 90.00% of variance
# 20 components needed to explain 95.00% of variance
# 30 components needed to explain 98.00% of variance
# 38 components needed to explain 99.00% of variance
# 64 components needed to explain 99.90% of variance

# %%
desired_variance = 0.99

#NOTE - uncomment 1 per run
pca = PCA(desired_variance)
# pca = PCA(n_components=2)
# pca = PCA(n_components=3)

pca.fit(X_scaled)
Xpca = pca.transform(X_scaled)

components = pca.components_

print(data_features.shape)
print(X_scaled.shape)
print(Xpca.shape)
print('Explained Variance Components:', pca.explained_variance_ratio_)
print('Desired Variance:', desired_variance)
print('Explained Variance:', np.sum(pca.explained_variance_ratio_))

filename = save_dir + '\\Xpca_f{:03d}'.format(pca.n_features_)+'_c{:03d}'.format(pca.n_components_)+'_v{:04d}'.format(int(np.sum(pca.explained_variance_ratio_)*10000))
print(filename)
np.save(filename + '.npy', Xpca)
# Out:
# (1000, 106)
# (1000, 106)
# (1000, 39)
# Explained Variance Components: [0.3117373  0.19996266 0.11082625 0.08438127 0.06038005 0.0306009
#  0.02482972 0.02237813 0.0156474  0.01391216 0.01285949 0.01020847
#  0.00979498 0.00770215 0.00738171 0.00653686 0.00543101 0.00528838
#  0.00480537 0.00444418 0.00413465 0.00362216 0.0034646  0.00324653
#  0.00295696 0.00260808 0.00246606 0.00234281 0.00233186 0.00207008
#  0.00181013 0.00161826 0.0015753  0.00143794 0.00138369 0.00134541
#  0.00115854 0.00103461 0.00086025]
# Desired Variance: 0.99
# Explained Variance: 0.9905763684446328
# C:\Users\alexa\Documents\GitHub\TCGA-kidney\Module2\Xpca_f106_c039_v9905

# %%
from mpl_toolkits.mplot3d import Axes3D

if Xpca.shape[1] == 2:
    fig = plt.figure()
    ax = fig.add_subplot(111)
    
    class1 = np.where(augmented_labels == 0) #Necrosis
    class2 = np.where(augmented_labels == 1) #Stroma
    class3 = np.where(augmented_labels == 2) #Tumor
    
    print('Class Count: %d, %d, %d' % (len(class1[0]), len(class2[0]), len(class3[0])))
    
    ax.scatter(Xpca[class1, 0], Xpca[class1, 1], marker='.', color='g')
    ax.scatter(Xpca[class2, 0], Xpca[class2, 1], marker='.', color='y')
    ax.scatter(Xpca[class3, 0], Xpca[class3, 1], marker='.', color='r')

    ax.set_xlabel('PC-1')
    ax.set_ylabel('PC-2')
    ax.set_title('2D PCA')
    plt.show()
    
    fig.savefig(save_dir + '\\2D.png')

elif Xpca.shape[1] == 3:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
        
    class1 = np.where(augmented_labels == 0) #Necrosis
    class2 = np.where(augmented_labels == 1) #Stroma
    class3 = np.where(augmented_labels == 2) #Tumor
    
    print('Class Count: %d, %d, %d' % (len(class1[0]), len(class2[0]), len(class3[0])))
    
    ax.scatter(Xpca[class1, 0], Xpca[class1, 1], Xpca[class1, 2], marker='.', color='g')
    ax.scatter(Xpca[class2, 0], Xpca[class2, 1], Xpca[class2, 2], marker='.', color='y')
    ax.scatter(Xpca[class3, 0], Xpca[class3, 1], Xpca[class3, 2], marker='.', color='r')

    ax.set_xlabel('PC-1')
    ax.set_ylabel('PC-2')
    ax.set_zlabel('PC-3')
    ax.set_title('3D PCA')
    plt.show()
    
    fig.savefig(save_dir + '\\3D.png')

# %% [markdown]
# ---
#
# ## Correlation Matrix

# %%
pca_df = pd.DataFrame.from_records(data_features)

# %%
correlation = pca_df.corr(method='pearson')
fig, ax = plt.subplots(figsize=(15, 15))
sb.heatmap(correlation, ax=ax, cmap='coolwarm', robust=True, cbar=True)
plt.title('Correlation Matrix - Original')
plt.show()

fig.savefig(save_dir + '\\correlation_original.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-ee0956dc047b> in <module>()
#       5 plt.show()
#       6
# ----> 7 fig.savefig(save_dir + '\\correlation_original.png')
#
# NameError: name 'save_dir' is not defined

# %%
pca_df = pd.DataFrame.from_records(Xpca)

# %%
correlation = pca_df.corr(method='pearson')
fig, ax = plt.subplots(figsize=(15, 15))
sb.heatmap(correlation, ax=ax, cmap='coolwarm', robust=True, cbar=True)
plt.title('Correlation Matrix - PCA')
plt.show()

fig.savefig(save_dir + '\\correlation_pca.png')

# %% [markdown]
# ---
#
# ## Minimum Redundancy Maximum Relevance (MRMR)

# %% [markdown]
# ---
#
# ## Random Forest / Gradient Boosting

# %%
from sklearn.ensemble import ExtraTreesClassifier

# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=20, random_state=0)
forest.fit(data_features, data_labels)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# %%
print("Rank:    Index Importance")
for f in range(data_features.shape[1]):
    print("Rank %2d: %5d (%f)" % (f+1, indices[f], importances[indices[f]], ))
# Out:
# Rank:    Index Importance
# Rank  1:   104 (0.047483)
# Rank  2:    37 (0.042031)
# Rank  3:     4 (0.041782)
# Rank  4:     5 (0.035395)
# Rank  5:     0 (0.031651)
# Rank  6:    13 (0.027734)
# Rank  7:    34 (0.024884)
# Rank  8:    74 (0.021493)
# Rank  9:    63 (0.021270)
# Rank 10:    77 (0.019207)
# Rank 11:    35 (0.017105)
# Rank 12:     7 (0.016161)
# Rank 13:   100 (0.013997)
# Rank 14:    24 (0.013744)
# Rank 15:     3 (0.012845)
# Rank 16:    60 (0.012664)
# Rank 17:    12 (0.012590)
# Rank 18:    49 (0.012532)
# Rank 19:    75 (0.011838)
# Rank 20:    30 (0.011526)
# Rank 21:    56 (0.011334)
# Rank 22:    33 (0.011164)
# Rank 23:   105 (0.010586)
# Rank 24:    36 (0.010559)
# Rank 25:    55 (0.010512)
# Rank 26:    52 (0.010498)
# Rank 27:    18 (0.010397)
# Rank 28:    10 (0.010266)
# Rank 29:    47 (0.010217)
# Rank 30:    48 (0.010160)
# Rank 31:    94 (0.009924)
# Rank 32:    41 (0.009832)
# Rank 33:    25 (0.009828)
# Rank 34:    54 (0.009703)
# ...

# %%
fig, ax = plt.subplots(figsize=(50, 10))
plt.title("Feature Importance")
plt.bar(range(0, data_features.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")

plt.xticks(range(0, data_features.shape[1], 1), indices)
plt.xlim([-1, data_features.shape[1]])
plt.xlabel('Feature #')
plt.xticks(rotation=90)
plt.ylabel('Importance')
plt.show()

# fig.savefig(save_dir + '\\random_forest_f{:03d}'.format(len(important_features)) + '.png')

# %%
# import cv2
# import copy
# from matplotlib import pyplot as plt
# import numpy as np
# from scipy.ndimage import gaussian_laplace as log

# class Pycode():

#     def __init__(self, fn):
#         self.img = cv2.imread(fn)

#     def centroids(self): #X
#         # Find the centroid of the 224x224x3 normalized image
#         # Return a tuple of 2 values, in the form of(x-centroid, y-centroid)
#         grayimg = cv2.cvtColor(self.img, cv2.COLOR_BGR2GRAY)
#         ret, thresh = cv2.threshold(grayimg, 127, 255, 0)
#         M = cv2.moments(thresh)
#         if M['m00'] != 0:
#             cX = int(M['m10'] / M['m00'])
#             cY = int(M['m01'] / M['m00'])
#         else:
#             return (0,0)
#         return (cX, cY)

#     def lapofgau(self): #?
#         # Convolute a gaussian kernel and a laplace kernel
#         return log(self.img, sigma=1)

#     def canny(self): #X
#         return cv2.Canny(self.img, 100, 200)

#     def sobel(self): #?
#         return cv2.Sobel(self.img, cv2.CV_64F, 1,1, ksize=5)

#     def calc_histogram(self): #X
#         hist = cv2.calcHist([self.img], [0], None, [256], [0, 256])
#         return hist

#     def hough_line(self): #NO
#         gray = cv2.cvtColor(self.img, cv2.COLOR_BGR2GRAY)
#         edges = self.canny()
#         lines = cv2.HoughLines(edges, 1, np.pi/180, 200)
#         imgcpy = copy.deepcopy(self.img)
#         print(lines)
#         for rho, theta in lines[0]:
#             a = np.cos(theta)
#             b = np.sin(theta)
#             x0 = a*rho
#             y0 = b*rho
#             x1 = int(x0 + 1000*(-b))
#             y1 = int(y0 + 1000*(a))
#             x2 = int(x0 - 1000*(-b))
#             y2 = int(y0 - 1000(a))
#             cv2.line(imgcpy, (x1,y1), (x2,y2), (0,0,255), 2)
#         return imgcpy

#     def fground_extract(self): #NO
#         # Extract the image foreground
#         mask = np.zeros(self.img.shape[:2], np.uint8)
#         bgdMode1 = np.zeros((1,65), np.float64)
#         fgdMode1 = np.zeros((1,65), np.float64)
#         cv2.grabCut(self.img, mask, (0,0,244,244), bgdMode1, fgdMode1, 5, cv2.GC_INIT_WITH_RECT)
#         mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
#         imgcpy = copy.deepcopy(self.img)
#         return imgcpy*mask2[:,:,np.newaxis]

#     def corner_detect(self): #X
#         # Harris Corner detect with OpenCV
#         gray = cv2.cvtColor(self.img, cv2.COLOR_BGR2GRAY)
#         gray = np.float32(gray)
#         dst = cv2.cornerHarris(gray, 2, 3, 0.04)
#         dst = cv2.dilate(dst, None)
#         # Apply thresholding
#         imgcpy = copy.deepcopy(self.img)
#         imgcpy[dst>0.015*dst.max()]=[0,255,0]
        
#         print(np.sum(dst>0.015*dst.max()))
        
#         return imgcpy

# x = Pycode(augmented_images_files[2][0])
# print(x.centroids())

# fig = plt.figure(figsize=(20, 20))
# plt.subplot(1, 5, 1)
# plt.xticks([])
# plt.yticks([])
# plt.grid(False)
# plt.imshow(cv2.cvtColor(x.lapofgau().astype(np.uint8), cv2.COLOR_BGR2RGB))
# plt.xlabel('1')
# plt.subplot(1, 5, 2)
# plt.xticks([])
# plt.yticks([])
# plt.grid(False)
# plt.imshow(cv2.cvtColor(x.canny().astype(np.uint8), cv2.COLOR_BGR2RGB))
# plt.xlabel('2')
# plt.subplot(1, 5, 3)
# plt.xticks([])
# plt.yticks([])
# plt.grid(False)
# plt.imshow(cv2.cvtColor(x.sobel().astype(np.uint8), cv2.COLOR_BGR2RGB))
# plt.xlabel('3')
# plt.subplot(1, 5, 4)
# plt.xticks([])
# plt.yticks([])
# plt.grid(False)
# plt.imshow(cv2.cvtColor(x.hough_line().astype(np.uint8), cv2.COLOR_BGR2RGB))
# plt.xlabel('4')
# plt.subplot(1, 5, 5)
# plt.xticks([])
# plt.yticks([])
# plt.grid(False)
# plt.imshow(cv2.cvtColor(x.corner_detect().astype(np.uint8), cv2.COLOR_BGR2RGB))
# plt.xlabel('5')

# %%
# kernel = np.ones((5,5), np.uint8)
# out = cv2.morphologyEx(can, cv2.MORPH_CLOSE, kernel)

# fig = plt.figure()
# plt.subplot(1, 2, 1)
# plt.xticks([])
# plt.yticks([])
# plt.grid(False)
# plt.imshow(cv2.cvtColor(can, cv2.COLOR_BGR2RGB))
# plt.xlabel('mask')
# plt.subplot(1, 2, 2)
# plt.xticks([])
# plt.yticks([])
# plt.grid(False)
# plt.imshow(cv2.cvtColor(out, cv2.COLOR_BGR2RGB))
# plt.xlabel('white mask')
# Out:
# Text(0.5,0,'white mask')

# %%
#mask

print(np.max(s))
s_mask = (s > 100).astype(np.uint8)*255

fig = plt.figure(figsize=(10, 10))
plt.subplot(1, 3, 1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(cv2.cvtColor(augmented_images[i], cv2.COLOR_BGR2RGB))
plt.subplot(1, 3, 2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(cv2.cvtColor(s, cv2.COLOR_BGR2RGB))
plt.subplot(1, 3, 3)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(cv2.cvtColor(s_mask, cv2.COLOR_BGR2RGB))
# Out:
# 150

# %%
img = cv2.imread(augmented_images_files[i][0])
Z = img.reshape((-1,3))

# convert to np.float32
Z = np.float32(Z)

# define criteria, number of clusters(K) and apply kmeans()
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 6
ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)

# Now convert back into uint8, and make original image
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))

cv2.imshow('res2',res2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from scipy import ndimage as ndi
from skimage.segmentation import watershed
from skimage.feature import peak_local_max

image = np.expand_dims(np.array(Image.open(augmented_images_files[i][0])).astype(np.uint8), axis=0)  

distance = ndi.distance_transform_edt(image)
local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)), labels=image)
markers = ndi.label(local_maxi)[0]
labels = watershed(-distance, markers, mask=image)

fig, axes = plt.subplots(ncols=3, figsize=(9, 3), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(image, cmap=plt.cm.gray)
ax[0].set_title('Overlapping objects')
ax[1].imshow(-distance, cmap=plt.cm.gray)
ax[1].set_title('Distances')
ax[2].imshow(labels, cmap=plt.cm.nipy_spectral)
ax[2].set_title('Separated objects')

for a in ax:
    a.set_axis_off()

fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-136-4748c11d3fd4> in <module>()
#       6
#       7 distance = ndi.distance_transform_edt(image)
# ----> 8 local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)), labels=image)
#       9 markers = ndi.label(local_maxi)[0]
#      10 labels = watershed(-distance, markers, mask=image)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\skimage\feature\peak.py in peak_local_max(image, min_distance, threshold_abs, threshold_rel, exclude_border, indices, num_peaks, footprint, labels, num_peaks_per_label)
#     143                                   exclude_border=exclude_border,
#     144                                   indices=False, num_peaks=num_peaks_per_label,
# --> 145                                   footprint=footprint, labels=None)
#     146
# ...

# %%
# # # image = Image.open(image_files[1])
# # pil_image = Image.open(image_files[1]).convert('RGB') 
# # open_cv_image = np.array(pil_image) 
# # # Convert RGB to BGR 
# # open_cv_image = open_cv_image[:, :, ::-1].copy() 

# print(image_files[1])
# img = cv2.imread(image_files[1], 0)
# current_image = np.expand_dims(np.array(Image.open(augmented_images_files[1]).astype(np.uint8), axis=0))
# out = extract_hsv(current_image)
# current_data_features = np.append(current_data_features, out[0][0:6], axis=0)
# s = out[2]
# vis2 = cv2.cvtColor(s, cv2.COLOR_GRAY2BGR)
# cv2.imshow('s', vis2)


# # img = cv2.imread('balls.jfif',0)

# img = cv2.medianBlur(img,5)
# print(img.shape)
# cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

# circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,100, param1=75,param2=40,minRadius=0,maxRadius=0)
# circles = np.uint16(np.around(circles))

# print(circles.shape)
# for i in circles[0,:]:
#     # draw the outer circle
#     cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
#     # draw the center of the circle
#     cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

# cv2.imshow('detected circles',cimg)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# print(data_features)

# %%
from __future__ import print_function
import cv2 as cv
import numpy as np
import argparse
import random as rng
rng.seed(12345)
def thresh_callback(val):
    threshold = val
    
    canny_output = cv.Canny(src_h, threshold, threshold * 2)
    
    
    contours, hierarchy = cv.findContours(canny_output, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    
    # Find the rotated rectangles and ellipses for each contour
    minRect = [None]*len(contours)
    minEllipse = [None]*len(contours)
    for i, c in enumerate(contours):
        minRect[i] = cv.minAreaRect(c)
        if c.shape[0] > 5:
            minEllipse[i] = cv.fitEllipse(c)
    # Draw contours + rotated rects + ellipses
    
    drawing = np.zeros((canny_output.shape[0], canny_output.shape[1], 3), dtype=np.uint8)
    
    for i, c in enumerate(contours):
        color = (rng.randint(0,256), rng.randint(0,256), rng.randint(0,256))
        # contour
        cv.drawContours(drawing, contours, i, color)
        # ellipse
        if c.shape[0] > 5:
            cv.ellipse(drawing, minEllipse[i], color, 2)
        # rotated rectangle
        box = cv.boxPoints(minRect[i])
        box = np.intp(box) #np.intp: Integer used for indexing (same as C ssize_t; normally either int32 or int64)
        cv.drawContours(drawing, [box], 0, color)
    
    
    cv.imshow('Contours', drawing)

# %%
data_dir = current_dir + '\\data_augmented'
image_file = glob.glob(data_dir + '/*.png')[29]
print(image_file)

src = np.array(Image.open(image_file)).astype(np.uint8)
stuff = extract_hsv(src)

# Convert image to gray and blur it
# src_gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
# src_gray = cv.blur(src_gray, (3,3))
src_h = stuff[0]
print(src.shape)

# source_window = 'Source'
# cv.namedWindow(source_window)
# cv.imshow(source_window, src)
# max_thresh = 255
# thresh = 100 # initial threshold
# cv.createTrackbar('Canny Thresh:', source_window, thresh, max_thresh, thresh_callback)
# thresh_callback(thresh)
# cv.waitKey()
# Out:
# C:\Users\alexa\Documents\GitHub\TCGA-kidney\data_original\Necrosis\Necrosis_35.png
# (512, 512, 3)
